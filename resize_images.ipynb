# %% [markdown]
# <a href="https://colab.research.google.com/github/shadabmalikcse/resize-images/blob/main/resize_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

from google.colab import files
uploaded = files.upload()

import cv2
import os

output_dir = "resized_images"
os.makedirs(output_dir, exist_ok=True)

for image_name in uploaded.keys():
    image = cv2.imread(image_name)

    # Get the original dimensions
    original_height, original_width = image.shape[:2]

    # Calculate the new dimensions
    new_width = original_width // 2
    new_height = original_height // 2

    # Resize the image
    resized_image = cv2.resize(image, (new_width, new_height))

    # Save the resized image
    resized_image_name = os.path.join(output_dir, f'resized_{image_name}')
    cv2.imwrite(resized_image_name, resized_image)

from google.colab import files

for image_name in uploaded.keys():
    resized_image_name = os.path.join(output_dir, f'resized_{image_name}')
    files.download(resized_image_name)
# Out:
# ...
#      <input type="file" id="files-abbfa1ef-547b-41e2-95ad-741782781369" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abbfa1ef-547b-41e2-95ad-741782781369">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
